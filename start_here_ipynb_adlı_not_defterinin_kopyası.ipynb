# %% [markdown]
# <a href="https://colab.research.google.com/github/tugberksncktr04/tugberksancaktar/blob/master/start_here_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table width="100%">
#     <tr style="">
#         <th style="text-align:left; padding:0px" width="5%">
#             <a href="https://www.marmara.edu.tr" target="_blank">
#                 <img src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/mu_logo.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="35%">
#             <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/name.png">
#         </th>
#         <th  width="20%">
#             &nbsp;
#         </th>
#         <th style="padding:0px" width="5%">
#             <a href="https://www.sababozpolat.com" target="_blank" padding="0px">
#                 <img align="center" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/hp.png">
#             </a>
#         </th>
#         <th style="padding:0px" width="5%">
#             <a href="mailto:saba.bozpolat@gmail.com" target="_blank">
#                 <img align="center" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/email.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="5%">
#             <a href="https://www.linkedin.com/in/saba-bozpolat-644856152/" target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/in.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="5%">
#             <a href="https://scholar.google.com.tr/citations?user=nSiJoMYAAAAJ&hl=en" target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/GS.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="5%">
#             <a href="https://www.researchgate.net/profile/Saba-Bozpolat" target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/RG.png">
#             </a>
#         </th>
#         <th style="padding:0px" width="5%">
#             <a href="https://www.youtube.com/channel/UC8-uOZud6UL7oCOE2UUBunA" target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/YT.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="5%">
#             <a href="https://github.com/sbbzplt" target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/GH.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="5%">
#             <a href="https://join.slack.com/t/mu-fzk/shared_invite/zt-13jtd6dtd-g9zD5P4Zu0m5P0Gt2PNReQ"
#                target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/slack.png">
#             </a>
#         </th>
#     </tr>
# </table>
# <table width="100%">
#     <tr style="background-color:white;">
#         <!-- <td style="text-align-left;padding:0px;" width="10%">
#             <a href="https://fef.marmara.edu.tr"
#                target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/fef.png">
#             </a>
#         </td> -->
#         <td style="padding:0px" width="25%">
#             <a href="http://fzk.fen.marmara.edu.tr"
#                target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/fzk.png">
#             </a>
#         </td>
#         <td width="10%">
#             &nbsp;
#         </td>
#         <td style="padding:0px;" width="65%">
#             <a href="https://www.sababozpolat.com/lectures/spring-semester/scientific-programming"
#                target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/comp2083.png">
#             </a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # **Table of Contents**
#
# ## Introduction to COMP2083
#
# [Syllabus](content/intro/II_01_syllabus.ipynb)
# &nbsp;|&nbsp;
# [Colab](content/intro/II_02_colab.ipynb)
# &nbsp;|&nbsp;
# [Github](content/intro/II_03_github.ipynb)
# &nbsp;|&nbsp;
# [Canvas](content/intro/II_04_canvas.ipynb)
# &nbsp;|&nbsp;
# [Slack](content/intro/II_05_slack.ipynb)
#
# ## Basics of Computational Technologies
#
# [What is a computer?](content/basics/BB_04_what_is_a_computer.ipynb)
# &nbsp;|&nbsp;
# [Inside a computer](content/basics/BB_08_inside_a_computer.ipynb)
# &nbsp;|&nbsp;
# [Hardware](content/basics/BB_12_hardware.ipynb)
# &nbsp;|&nbsp;
# [Software](content/basics/BB_16_software.ipynb)
# &nbsp;|&nbsp;
# [Programming Languages](content/basics/BB_20_programming_language.ipynb)
#
# ## Fundamentals of Algorithm
#
# [What is an algorithm?](content/algorithm/AA_04_algorithm.ipynb)
# <!-- &nbsp;|&nbsp; -->
# <!-- [How to break a problem?](content/algorithm/AA_08_chunks.ipynb) -->
# <!-- &nbsp;|&nbsp; -->
# <!-- [How to write an algorithm?](content/algorithm/AA_12_how_to_write_an_algorithm.ipynb) -->
# <!-- &nbsp;|&nbsp; -->
#
# ## Data and Its Storage
#
# [Data](content/python/Data04_data.ipynb)
# &nbsp;|&nbsp;
# [Variable](content/python/Data08_variable.ipynb)
# &nbsp;|&nbsp;
# [Assignment Operator](content/python/DD_12_assignment_operator.ipynb)
#
# ## Primitive Data Types
#
# [Integer](content/python/PD_04_integer.ipynb)
# &nbsp;|&nbsp;
# [Float](content/python/PD_08_float.ipynb)
# &nbsp;|&nbsp;
# [String](content/python/PD_12_string.ipynb)
# &nbsp;|&nbsp;
# [Boolean](content/python/PD_16_boolean.ipynb)
# &nbsp;|&nbsp;
# [Type Casting](content/python/PD_20_type_casting.ipynb)
#
# ## Data Containers
# [List](content/python/DC_04_list.ipynb)
# &nbsp;|&nbsp;
# [Set](content/python/DC_08_set.ipynb)
# &nbsp;|&nbsp;
# [Tuple](content/python/DC_12_tuple.ipynb)
# &nbsp;|&nbsp;
# [Dictionary](content/python/DC_16_dictionary.ipynb)
#
# ## Fundamental Operators
#
# [What is an Operator?](content/python/FO_04_definition_of_operators.ipynb)
# &nbsp;|&nbsp;
# [Arithmetic Operators](content/python/FO_08_arithmetic_operators.ipynb)
# &nbsp;|&nbsp;
# [Comparison Operators](content/python/FO_12_comparison_operators.ipynb)
# &nbsp;|&nbsp;
# [Assignment Operators](content/python/FO_16_assignment_operators.ipynb)
#
# [Logical Operators](content/python/FO_20_logical_operators.ipynb)
# &nbsp;|&nbsp;
# [Membership Operators](content/python/FO_24_membership_operators.ipynb)
# &nbsp;|&nbsp;
# [Operators Precedence](content/python/FO_28_operators_precedence.ipynb)
#
# ## Decision Making
#
# [Conditions](content/python/DM_04_conditions.ipynb)
# &nbsp;|&nbsp;
# [Branching](content/python/DM_08_branching.ipynb)
# &nbsp;|&nbsp;
# [If Blocks](content/python/DM_12_if.ipynb)
# &nbsp;|&nbsp;
# [Nested If Blocks](content/python/DM_16_nested_if.ipynb)
#
# ## Loops
#
# [General Structure of Loops](content/python/LL_04_general_structure.ipynb)
# &nbsp;|&nbsp;
# [Range](content/python/LL_08_range.ipynb)
# &nbsp;|&nbsp;
# [For Loops](content/python/LL_12_for.ipynb)
#
# [While Loops](content/python/LL_16_while.ipynb)
# &nbsp;|&nbsp;
# [Continue](content/python/LL_20_continue.ipynb)
# &nbsp;|&nbsp;
# [Pass](content/python/LL_24_pass.ipynb)
# &nbsp;|&nbsp;
# [Break](content/python/LL_28_break.ipynb)
#
# ## Abstraction & Functions
#
# [What is abstraction?](content/python/AF_04_abstraction.ipynb)
# &nbsp;|&nbsp;
# [Global Scope](content/python/AF_08_global.ipynb)
# &nbsp;|&nbsp;
# [Local Scope](content/python/AF_12_local.ipynb)
# &nbsp;|&nbsp;
# [Fundamental Logic of Functions](content/python/AF_16_fundamental_logic.ipynb)
#
# [Inputs of a Function](content/python/AF_20_inputs.ipynb)
# &nbsp;|&nbsp;
# [Body of a Function](content/python/AF_24_body.ipynb)
# &nbsp;|&nbsp;
# [Outputs of a Function](content/python/AF_28_outputs.ipynb)
#
# ## Data Visualization
#
# [Matplotlib](content/data_visualization/DV_04_Matplotlib.ipynb)
#
# ## From Continuum to Grid
#
# [Symbolic Calculation](content/grid/CG_04_symbolic.ipynb)
# &nbsp;|&nbsp;
# [Numeric Calculation](content/grid/CG_08_numeric.ipynb)
# &nbsp;|&nbsp;
# [Continuum](content/grid/CG_12_continuum.ipynb)
# &nbsp;|&nbsp;
# [Grid](content/grid/CG_16_grid.ipynb)
# &nbsp;|&nbsp;
# [Definition of a Grid](content/grid/CG_20_definition_of_grid.ipynb)
#
#
# ----------------------------
# ----------------------------
# **BURADAN DEVAM**
# ----------------------------
# ----------------------------
# ----------------------------
#
# ## Numerical Derivation
#
# [Forward Derivation](content/ND_29_Numerical_Derivation.ipynb)
# &nbsp;|&nbsp;
# [Forward Derivation Applications](content/ND_29_Numerical_Derivation.ipynb)
# &nbsp;|&nbsp;
# [Backward Derivation](content/ND_29_Numerical_Derivation.ipynb)
#
# [Backward Derivation Applications](content/ND_29_Numerical_Derivation.ipynb)
# &nbsp;|&nbsp;
# [Central Derivation](content/ND_29_Numerical_Derivation.ipynb)
# &nbsp;|&nbsp;
# [Central Derivation Applications](content/ND_29_Numerical_Derivation.ipynb)
#
# [Higher Order Derivations - Definition](content/ND_29_Numerical_Derivation.ipynb)
# &nbsp;|&nbsp;
# [Higher Order Derivations - Implementation](content/ND_29_Numerical_Derivation.ipynb)
#
# [Higher Order Derivations - Applications](content/ND_29_Numerical_Derivation.ipynb)
#
# ## Numerical Integration
#
# [Trapezoidal Method](content/NI_29_Numerical_Derivation.ipynb)
# &nbsp;|&nbsp;
# [Secant Method](content/NI_29_Numerical_Derivation.ipynb)
#
# ## Integrating Differential Equations
#
# [Euler's Method](content/DE_29_Numerical_Derivation.ipynb)
# &nbsp;|&nbsp;
# [Application of Euler's Method to 1st Order Differential Equation](content/DE_29_Numerical_Derivation.ipynb)
#
# [Order Reduction of Differential Equations](content/DE_29_Numerical_Derivation.ipynb)
# &nbsp;|&nbsp;
# [Application of Euler's Method to Mechanics Problems](content/DE_29_Numerical_Derivation.ipynb)
#
# [Application of Euler's Method to Electric and Magnetism Problems](content/DE_29_Numerical_Derivation.ipynb)
#
# [Application of Euler's Method to Modern Physics Problems](content/DE_29_Numerical_Derivation.ipynb)
